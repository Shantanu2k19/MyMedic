# %%
import cv2
from PIL import Image

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytesseract
import cv2
import tempfile
import re
from PIL import Image

# %%
img = cv2.imread("resources/max.jpg", flags=cv2.IMREAD_GRAYSCALE)

# %%
img = cv2.imread("resources/max.jpg", flags=cv2.IMREAD_GRAYSCALE)

_, new_img = cv2.threshold(img,150,255,cv2.THRESH_BINARY)
Image.fromarray(new_img).show()  #popup view, doesnot work in colab

# %%
import matplotlib.pyplot as plt
plt.imshow(new_img, cmap='gray')
plt.axis('off')
plt.show()

# %%
new_img = cv2.adaptiveThreshold(
    img, 255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY,
    61,
    11
)

# %%
plt.imshow(new_img, cmap='gray')
plt.axis('off')
plt.show()

# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'
text = pytesseract.image_to_string(new_img, lang='eng',config='--psm 6 --oem 1')
print(text)
# Out:
# ag Healthcare i RE DS ae ce A \
# Q Patient Name: r. Shantanu ees a oy _i Location: Shalimar Bagh of ey we oe 4 poe
# J Age / Sex: > - 21 year(s) 3 month(s) 1 day(s) /Male =~: Dates... ~ 2 Thursday, June 23, 2022 3:55PM ieee
# : : ‘Max doe . SHBG.454506 moe ces : ee a Invoice No: _ SBCR429749 we ce hh - 7
# pg SS Sat cae g gt RE OE ae eee ae TA
# : ~ Allergy: No Known Allergy” OR ° ee ee Bp ee yy
# 3 oe ee ee EM YY
# Le CAP ISOTROIN 20 MG ALT DAY, APTER MEALS Lh Se Pee oe o\
# ~ .. gSeefduo gel once daily night time 1 HR WASH 8 ee ee Ber ee |
# 5 (Y=. eélyzap spray twice daily ne ee Pe DO eae oY
# “lindas a lotion once gaily nighttime "2 ee CEE ee A
# Aone UV gel spf Wie er ree BB ae gee
# pt be XESHBOOST AD SHAMPOO ALTDAY Corn ep BOS GE Ce
# =  f\_YETIDERM LOTION ONCE DAILY 2) SES CE I En - y
# M | --= “review after 14 days 2 i eda 4 a EO ee ae bee a Bi ia\
# eee A whe EE gle Oe ee ee |
# Rene i alee ya its Ei EE 8 ae Re oe LV eed
# ee ee ps Rat Ay
# ...

# %%
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'
text = pytesseract.image_to_string(new_img, lang='eng')
print(text)
# Out:
#
#
# Page 1 ets. oS Q ee oes
#
#
#
#
#
#
# Patient Name: - Mr, Shantanu « : es
# 21 year(s) 3 month(s) 1 caval IMale -
#
# Age | Sex:
#
# ‘Maxtd: . SHBG.454506 -
#
# Doctor Name: ~ Or. Rahul Arora ees
# Y Dermatology ee
#
#
#
#
#
# Speciality °
#
#
#
# - Allergy: No Known Allergy '
#
#
#
#
#
# Provisional Diagnosis > *
#
# av gd 3
#
#
#
#
#
#
#
# oh Medicine Advised o sp
#
# aera - OghP ISOTROIN 20 MG ALT T DAY Y AFTER MEAL
# : Bede gel once daily night time 4 HR WASH
# ~.-« SElyZap spray twice daily “a
#
# ee *clindac a lotion-once daily: night ti
# | > oe Acne UV gel spf 30 S
# y’ | FASHX FACEWASH (7 ©
# a MG OOM Lt AD “SHAMPOO ALT DAY
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# iIDERM LOTION ONCE DAILY :
#
#
#
#
#
#
# M | = “teview after 14 days SE
# [= ne |
# a : ches ee Ba anu AigsBul Arora 7
# / “ associate a ee
#
# Consultant - Denia, a8 sate
#
# | 4 A
# _ ln BORG mio
#
# Room No. scart
#
#
#
#
#
#
#
#
#
#
#
#
# Max ‘Healthcare Institute Limited a ;
# ...

# %%
from pytesseract import Output

# %%
data = pytesseract.image_to_data(new_img, output_type=Output.DICT)

# %%
import re

def is_valid_text(text):
    # Check if text is an empty string
    if not text:
        return False
    
    # Define a regular expression pattern to match alphanumeric characters
    pattern = re.compile(r'^[a-zA-Z0-9]+$')
    
    # Use the match function to check if the text matches the pattern
    if pattern.match(text):
        return True
    else:
        return False

# Example usage:
text1 = "Hello123"  # Contains only alphanumeric characters
text2 = "Hello!@#"   # Contains special characters
text3 = "d   d    "           # Empty string

print(is_valid_text(text1))  # Output: True
print(is_valid_text(text2))  # Output: False
print(is_valid_text(text3))  # Output: False
# Out:
# True
# False
# False

# %%
import re

def clean_text(text):
    # Remove special characters
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # Replace multiple spaces with a single space
    text = re.sub(r'\s+', ' ', text)
    return text.strip()  # Remove leading and trailing spaces

# Example usage:
text = "Hello! This is an example text with $pecial characters and   multiple     spaces  !"
cleaned_text = clean_text(text)
print(cleaned_text)
# Out:
# Hello This is an example text with pecial characters and multiple spaces

# %%
img_with_boxes = new_img.copy()

# Iterate over each block
n_blocks = len(data['text'])
block_num = 0
for i in range(n_blocks):
    if int(data['conf'][i]) > 0:  # Only consider text with confidence > 0
        if data['block_num'][i] != block_num:
            block_num = data['block_num'][i]
            print(f"Block {block_num}:")
            print(data['text'][i])

        (x, y, w, h) = (data['left'][i], data['top'][i], data['width'][i], data['height'][i])
        cv2.rectangle(img_with_boxes, (x, y), (x + w, y + h), (0, 255, 0), 2)
        cv2.putText(img_with_boxes, str(block_num), (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36, 255, 12), 2)
        
        print(f"Text: {data['text'][i]}")
        print(f"  Bounding Box: ({x}, {y}, {w}, {h})")
        print(f"  Confidence: {data['conf'][i]}")
        print("\n")

# Convert BGR to RGB for displaying with matplotlib
img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)

# Display the image with bounding boxes
plt.figure(figsize=(10, 10))
plt.imshow(img_rgb)
plt.title("Image with OCR Bounding Boxes")
plt.axis('off')
plt.show()
# Out:
# Block 1:
#
# Text:
#   Bounding Box: (0, 0, 3000, 790)
#   Confidence: 95
#
#
# Block 2:
# Page
# Text: Page
#   Bounding Box: (1942, 708, 189, 113)
#   Confidence: 48
#
#
# Text: 1
#   Bounding Box: (2084, 704, 41, 121)
#   Confidence: 81
#
#
# Text: ets.
#   Bounding Box: (2077, 716, 225, 171)
#   Confidence: 30
#
#
# Text: ee
#   Bounding Box: (2360, 702, 44, 80)
#   Confidence: 36
#
#
# Text: oes
#   Bounding Box: (2416, 705, 97, 79)
#   Confidence: 5
#
#
# Block 3:
#
# Text:
#   Bounding Box: (0, 818, 3000, 173)
#   Confidence: 95
#
#
# Text:
#   Bounding Box: (1404, 710, 1596, 223)
#   Confidence: 95
#
#
# Text:
#   Bounding Box: (0, 991, 72, 79)
#   Confidence: 95
#
#
# Text:
#   Bounding Box: (1105, 933, 1895, 79)
#   Confidence: 95
#
#
# Text:
#   Bounding Box: (0, 1070, 72, 71)
#   Confidence: 95
#
#
# Text:
#   Bounding Box: (1076, 1012, 1924, 129)
#   Confidence: 95
#
#
# Text:
#   Bounding Box: (0, 1141, 262, 85)
#   Confidence: 95
#
#
# Block 4:
# Patient
# ...

# %%
img = cv2.imread("resources/max.jpg", flags=cv2.IMREAD_GRAYSCALE)
plt.figure(figsize=(10, 10))
plt.imshow(new_img2)
plt.title("grey")
plt.axis('off')
plt.show()

img_color = cv2.imread("resources/max.jpg")
img_color = cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(img_color)
plt.title("color")
plt.axis('off')
plt.show()
# cv2.imwrite('output_image2.png', img_color, [cv2.IMWRITE_PNG_COMPRESSION, 0])


_, new_img = cv2.threshold(img,150,255,cv2.THRESH_BINARY)
plt.figure(figsize=(10, 10))
plt.imshow(new_img)
plt.title("new_img")
plt.axis('off')
plt.show()

new_img = cv2.adaptiveThreshold(
    img, 255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY,
    61,
    11
)
plt.figure(figsize=(10, 10))
plt.imshow(new_img)
plt.title("guass")
plt.axis('off')
plt.show()

# %%
img = cv2.imread("resources/max.jpg", flags=cv2.IMREAD_GRAYSCALE)

new_img = cv2.adaptiveThreshold(
    img, 255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY,
    61,
    11
)

# %%
img = cv2.imread("resources/max.jpg", flags=cv2.IMREAD_GRAYSCALE)
imgCol = cv2.imread("resources/max.jpg")
cv2.imwrite('imgColoutput_image.png', imgCol, [cv2.IMWRITE_PNG_COMPRESSION, 0])

new_img = cv2.adaptiveThreshold(
    img, 255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY,
    61,
    11
)

data = pytesseract.image_to_data(new_img, output_type=Output.DICT)

# Create a dictionary to store blocks
blocks = {}

# Iterate over each text element
for i in range(len(data['text'])):
    if int(data['conf'][i]) > 0:  # Only consider text with confidence > 0
        block_num = data['block_num'][i]
        text = data['text'][i]
        text = clean_text(text)
        if text == "":
            continue
        left, top, width, height = data['left'][i], data['top'][i], data['width'][i], data['height'][i]

        # Add the text to the corresponding block
        if block_num not in blocks:
            blocks[block_num] = {'text': text, 'left': left, 'top': top, 'width': width, 'height': height}
        else:
            # Extend the boundaries of the block
            blocks[block_num]['left'] = min(blocks[block_num]['left'], left)
            blocks[block_num]['top'] = min(blocks[block_num]['top'], top)
            blocks[block_num]['width'] = max(blocks[block_num]['width'], left + width - blocks[block_num]['left'])
            blocks[block_num]['height'] = max(blocks[block_num]['height'], top + height - blocks[block_num]['top'])
            blocks[block_num]['text'] += ' ' + text  # Concatenate additional text

# Create a copy of the image to draw the rectangles
img_with_blocks = imgCol.copy()

# Draw a rectangle around each block and print text
new_block_num = 1
text_data = {}
for block_num, block_data in blocks.items():
    left, top, width, height = block_data['left'], block_data['top'], block_data['width'], block_data['height']
    cv2.rectangle(img_with_blocks, (left, top), (left + width, top + height), (0, 102, 255), 4)
    cv2.putText(img_with_blocks, str(block_num), (left, top - 10), cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 0, 0), 4)
    # print(f"Block {new_block_num} Text: {block_data['text']}")
    text_data[str(new_block_num)]= block_data['text']
    new_block_num+=1
    
# Convert BGR to RGB for displaying with matplotlib

# Display the image with bounding boxes around blocks
# plt.figure(figsize=(10, 10))
# plt.imshow(img_rgb)
# plt.title("Image with OCR Bounding Boxes Around Blocks")
# plt.axis('off')
# plt.show()

cv2.imwrite('output_image.png', img_with_blocks, [cv2.IMWRITE_PNG_COMPRESSION, 0])

for key, value in text_data.items():
    print(f"Key: {key}, Value: {value}")
# Out:
# Key: 1, Value: Page 1 ets ee oes
# Key: 2, Value: Patient Name Mr Shantanu es years 3 months 1 caval IMale
# Key: 3, Value: Age Sex Maxtd SHBG454506 Doctor Name Or Rahul Arora ees ee
# Key: 4, Value: Speciality
# Key: 5, Value: Allergy No Known Allergy
# Key: 6, Value: Provisional Diagnosis
# Key: 7, Value: av gd 3
# Key: 8, Value: oh Medicine Advised sp aera ISOTROIN 20 MG ALT T DAY Y AFTER MEAL gel once daily night time 4 HR WASH spray twice daily a ee clindac a lotiononce daily night ti oe Acne UV gel spf 30 FASHX 7 a MG Lt AD SHAMPOO ALT DAY
# Key: 9, Value: iIDERM LOTION ONCE DAILY
# Key: 10, Value: M teview after 14 days SE ne a ches ee Ba anu Arora 7 associate a ee
# Key: 11, Value: Consultant a8
# Key: 12, Value: 4 A ln BORG mio
# Key: 13, Value: Room No scart
# Key: 14, Value: Max Healthcare Institute Limited a Regd Office 401 4th Floor Man Excellenza S NV Road
# Key: 15, Value: Vile Parle West Mumbai Maharashtra 400 056 om Ty F9122 2610 046162 Be eS
# ...

# %%
img = cv2.imread("resources/max.jpg", flags=cv2.IMREAD_GRAYSCALE)

# %%
def processing1():
    img = cv2.imread("resources/max.jpg", flags=cv2.IMREAD_GRAYSCALE)
    _, new_img = cv2.threshold(img,150,255,cv2.THRESH_BINARY)
    
    new_img = cv2.adaptiveThreshold(
        img, 255,
        cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
        cv2.THRESH_BINARY,
        61,
        11
    )
    plt.figure(figsize=(10, 10))
    plt.imshow(new_img)
    plt.title("Image with OCR Blwmds")
    plt.axis('off')
    plt.show()
    cv2.imwrite('im1.png', new_img, [cv2.IMWRITE_PNG_COMPRESSION, 0])


    return new_img

pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'
text = clean_text2(pytesseract.image_to_string(processing1(), lang='eng',config='--psm 6 --oem 1'))
print(text)
# Out:
# (72.0, 72.0)

# %%
def denoise_image(image):
    # Apply non-local means denoising
    denoised_image = cv2.fastNlMeansDenoisingColored(image, None, 10, 10, 7, 21)
    return denoised_image

img = cv2.imread("resources/max.jpg")
img = denoise_image(img)
cv2.imwrite('denoise.png', new_img, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True

# %%
def processing2():
    image = cv2.imread("resources/max.jpg")

    # Convert to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Apply adaptive thresholding
    thresh = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 61, 11)
    
    # Remove noise with Gaussian blur
    blur = cv2.GaussianBlur(thresh, (5, 5), 0)
    
    # Perform text region detection, denoising, deskewing, etc.
    pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'
    text = pytesseract.image_to_string(blur, lang='eng',config='--psm 6 --oem 1')
    print(clean_text2(text))
    # Perform OCR on preprocessed image using Tesseract
    # (Insert your OCR code here)
   
    
    plt.figure(figsize=(10, 10))
    plt.imshow(blur)
    cv2.imwrite('im1blur.png', blur, [cv2.IMWRITE_PNG_COMPRESSION, 0])

    plt.title("Image with OCR Blwmds")
    plt.axis('off')
    plt.show()

processing2()
# Out:
# pideneies eee NRE Ria ay eae ee es e Ne MM a t LEU DPS UE den ls ed ot Ae Pagetofi 0 it 2 i ame Mr Shantanu ce er Te te OE Ohba ial EP er vA a5 Pa m awartey 3 months 1 aye y Location ShalimarBagh oA 4 eSex ears 3 months ays Male 2 wo LE TA eday ee aes ms Ag ee eden suse s day Male cont Date oe Thursday June 23 2022 355 PM Ri AY Maxid 94506 2 feu ehE Eh Invoice No SBCR429749 yo Ay 3 octor Name OrRahulArora Referred By SELF 87 oy POM So fg LESSORS oe PRE ED eee gE OS TEE ES a po AR 4 allergy NoKnown Allergy 5 Sse Ee Se AE SP TE Ss oy Provisional Diagnosis ne eae i Bit ane Ge oe lbh ae A Ono Bp s a 4 avgd3 yh ES eee ee oe ee ee By Bre Be Py pee Le UZAP ISOTROIN 20 MG ALT DAY AFTER MEALS ee CT e6duo gel once daily night time 1HR WASH seh gs tee Peg ie Ris Sin ers ey sn eyzap spray twice daily Pon TG Nae TEP es OME ey oe fos oo ae aoton once daly nighttime DPE ES ESN oo de ph Rane UV gel spf 308 HEE SIRE yh ES age EY J pe Sadi CASH X FACEWASH ee eo re ee ee RB ey SMG _ KESHBOOST AD SHAMPO
# ...

# %%
import re

def clean_text2(text):
    # Remove special characters except newline
    text = re.sub(r'[^\w\s\n]', '', text)
    # Replace multiple spaces with a single space
    text = re.sub(r'\s+', ' ', text)
    return text.strip()  # Remove leading and trailing spaces

# Example usage:
text = "Hello! This is an example text with $pecial characters and   multiple     spaces  !\nNew line."
cleaned_text = clean_text(text)
print(cleaned_text)
# Out:
# Hello This is an example text with pecial characters and multiple spaces New line

# %%
def get_image_dpi(image_path):
    with Image.open(image_path) as img:
        dpi = img.info.get("dpi")
        return dpi
