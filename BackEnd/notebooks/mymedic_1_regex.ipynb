# %%
pip install opencv-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 21.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 22.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 23.7 MB/s eta 0:00:0031m24.6 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from PIL import Image

# %%
img = cv2.imread("resources/dark_image.jpg", flags=cv2.IMREAD_GRAYSCALE)

# %%
_, new_img = cv2.threshold(img,150,255,cv2.THRESH_BINARY)
Image.fromarray(new_img).show()  #popup view, doesnot work in colab

# %%
import matplotlib.pyplot as plt
plt.imshow(new_img, cmap='gray')
plt.axis('off')
plt.show()

# %%
#adaptive made it better

new_img = cv2.adaptiveThreshold(
    img, 255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY,
    61,
    11
)

# %%
plt.imshow(new_img, cmap='gray')
plt.axis('off')
plt.show()

# %%
# !pip install pdf2image

# %%
pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'
text = pytesseract.image_to_string(new_img, lang='eng',config='--psm 6 --oem 1')
print(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'
#       2 text = pytesseract.image_to_string(new_img, lang='eng',config='--psm 6 --oem 1')
#       3 print(text)
#
# NameError: name 'pytesseract' is not defined

# %%
#NOW USING PDF

# %%
from pdf2image import convert_from_path

# %%
#!apt-get install poppler-utils
#!apt-get install libpoppler-cpp-dev

# %%
pages = convert_from_path('resources/patient_details/pd_1.pdf')

# %%
pages
# Out:
# [<PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1867x2000>,
#  <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=2000x1398>]

# %%
plt.imshow(pages[0])
plt.axis('off')
plt.show()

# %%
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'
text = pytesseract.image_to_string(pages[0], lang='eng')
print(text)
# Out:
#
#
# 47112/2020
#
#
#
# Patient Medical Record
#
#
#
# Patient Information Birth Date
# Kathy Crawford May 6 1972
# (737) 988-0851 Weight’
# 9264 Ash Dr 95
# New York City, 10005 .
# United States Height:
# 190
# In Case of Emergency
# a _ a _
# Simeone Crawford 9266 Ash Dr
# New York City, New York, 10005
# Home phone United States
# (990) 375-4621
# Work phone
# Genera! Medical History
# . : a ee
#
#
#
# Chicken Pox (Varicella):
#
# IMMUNE
#
# Have you had the Hepatitis B vaccination?
#
# No
#
# List any Medical Problems (asthma, seizures, headaches):
#
# Migraine
